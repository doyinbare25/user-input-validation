# %% [markdown]
# ![login_img](login_img.jpg)

# %% [markdown]
# You recently joined a small startup as a junior developer. The product managers have come to you for help improving new user sign-ups for the company's flagship mobile app.
#
# There are lots of invalid and incomplete sign-up attempts crashing the app. Before creating new accounts, you suggest standardizing validation checks by writing reusable Python functions to validate names, emails, passwords, etc. The managers love this idea and task you with coding core validation functions for improving sign-ups. It's your job to write these custom functions to check all user inputs to ensure they meet minimum criteria before account creation to reduce crashes.

# %%
# Re-run this cell
# Preloaded data for validating email domain.
top_level_domains = [
    ".org",
    ".net",
    ".edu",
    ".ac",
    ".gov",
    ".com",
    ".io"
]

# %%
# Start coding here. Use as many cells as you need.
def validate_name(name):
    if type(name) != str:
        #Check if the data type of the name is a string format.
        #print(f" the name '{name}' is not an acceptable format of name")
        return False
    # elif len(name) == 0:
    #     #check if the user entered an input at all
    #     #print("You have not enetered any nameS")
    #     return False
    elif len(name) <= 2:
        #check if the user's name is less than 2 digits.
        #print(f"{name} is of length {len(name)} and it's not acceptable")
        return False
    else:
        #the user must have entered a correct name format. this is acceptable.
        pass
    return True


def validate_email(email):
    if not '@' in email:
        #chek if the '@' symbol is contained in the user's email address.
        #print("the '@' sign is missing in your email. Kindly check and try again")
        return False

    for top_level_domain in top_level_domains:
        '''
        check if the domain name provided by the user aligns with the any of acceptable    domain names.
        
        '''
        if top_level_domain in email:
            return True
    else:
        pass
        return False
